# %%
# %matplotlib notebook

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os 
import json
import sys
from collections import namedtuple
import pandas as pd
import re
Benchmark = namedtuple('Benchmark', 'isPolling iodepth numjobs GenIOPS ActualIOPS P99_lat cpu_idleness')
NumJobs = [1]
IODepth = [1, 2, 4,6, 8,10]
IOPS = (100000, 200000, 300000, 400000, 500000, 600000, 700000)

entries = os.listdir("./")
json_files = [f for f in entries if f.endswith("json")]
benchmark_record = []

for file in json_files:
#     print(file)
    with open(file) as fd:
        try:
            output = fd.read()
#             print(output)
            P99_lat = re.findall("\|*99.0th=\[(\d+)\]", output)
            assert len(P99_lat) == 1
            P99_lat = int(P99_lat[0])

            cpu_idle = re.findall("system: (\d+.\d+)%", output)
            assert len(cpu_idle) == 1
            cpu_idle = float(cpu_idle[0])



#             actual_iops = re.findall("iops.+avg=(\d+)", output)

            actual_iops = re.findall("IOPS=(.+)k,", output)
#             print(actual_iops)
            assert len(actual_iops) == 1
            actual_iops = float(actual_iops[0])*1000
        except:
            sys.stderr.write("error loading json %s" % file, file=sys.stdout)
            exit(1)
    sss = file.split("-")
    is_polling = 1 if sss[0]=="polling" else 0
    iodepth = int(sss[1])
    numjobs = int(sss[2])
    gen_iops = int(sss[3].split(".")[0])
    b1 = Benchmark(is_polling, \
        iodepth, \
        numjobs, \
        gen_iops, \
        actual_iops, \
        P99_lat,\
        cpu_idle)

        
    benchmark_record.append(b1)

df = pd.DataFrame(benchmark_record)
df["CPU_util"] =  100 - df["cpu_idleness"]
df["iops_per_cpuutil"] =  df["ActualIOPS"] / df["CPU_util"]
# Out:
# polling-1-1-500000.json
# polling-2-1-300000.json
# blocking-10-1-100000.json
# blocking-2-1-300000.json
# polling-2-1-400000.json
# polling-10-1-300000.json
# blocking-6-1-600000.json
# polling-6-1-200000.json
# blocking-8-1-100000.json
# polling-2-1-200000.json
# polling-6-1-100000.json
# blocking-2-1-200000.json
# polling-8-1-600000.json
# polling-8-1-500000.json
# blocking-4-1-600000.json
# polling-4-1-100000.json
# blocking-6-1-700000.json
# blocking-6-1-400000.json
# blocking-8-1-300000.json
# blocking-1-1-300000.json
# polling-8-1-700000.json
# polling-6-1-300000.json
# blocking-2-1-400000.json
# blocking-6-1-200000.json
# polling-2-1-100000.json
# blocking-10-1-600000.json
# polling-8-1-300000.json
# polling-6-1-400000.json
# blocking-10-1-500000.json
# polling-2-1-500000.json
# polling-1-1-100000.json
# blocking-6-1-100000.json
# polling-4-1-700000.json
# polling-6-1-700000.json
# polling-8-1-400000.json
# blocking-8-1-600000.json
# polling-6-1-500000.json
# blocking-4-1-100000.json
# blocking-1-1-400000.json
# polling-1-1-300000.json
# blocking-1-1-500000.json
# blocking-10-1-200000.json
# blocking-4-1-700000.json
# blocking-6-1-300000.json
# polling-2-1-600000.json
# blocking-4-1-400000.json
# blocking-1-1-100000.json
# polling-10-1-600000.json
# blocking-2-1-100000.json
# polling-2-1-700000.json
# polling-10-1-100000.json
# blocking-4-1-200000.json
# polling-8-1-100000.json
# blocking-2-1-700000.json
# blocking-1-1-600000.json
# blocking-10-1-300000.json
# polling-4-1-500000.json
# polling-1-1-700000.json
# polling-1-1-600000.json
# blocking-2-1-600000.json
# blocking-4-1-300000.json
# blocking-8-1-200000.json
# polling-4-1-300000.json
# blocking-8-1-400000.json
# polling-4-1-600000.json
# blocking-1-1-700000.json
# polling-10-1-700000.json
# polling-6-1-600000.json
# blocking-10-1-700000.json
# polling-1-1-400000.json
# blocking-1-1-200000.json
# polling-8-1-200000.json
# blocking-8-1-500000.json
# blocking-2-1-500000.json
# blocking-10-1-400000.json
# blocking-6-1-500000.json
# polling-1-1-200000.json
# polling-4-1-200000.json
# polling-10-1-200000.json
# blocking-4-1-500000.json
# blocking-8-1-700000.json
# polling-10-1-500000.json
# polling-10-1-400000.json
# polling-4-1-400000.json

# %%
df
# Out:
#     isPolling  iodepth  numjobs  GenIOPS  ActualIOPS  P99_lat  cpu_idleness  \
# 0           1        1        1   500000       56347    10944         71.63
# 1           1        2        1   300000      101014    14784         71.71
# 2           0       10        1   100000       85427    33024         86.76
# 3           0        2        1   300000      121906    15296         88.80
# 4           1        2        1   400000      103407    14784         71.74
# ..        ...      ...      ...      ...         ...      ...           ...
# 79          0        4        1   500000      189235    22656         86.08
# 80          0        8        1   700000      178629    32384         88.38
# 81          1       10        1   500000      338291    36608         71.70
# 82          1       10        1   400000      339878    36096         71.66
# 83          1        4        1   400000      214982    19072         71.61
#
#     CPU_util  iops_per_cpuutil
# 0      28.37       1986.147339
# 1      28.29       3570.661011
# 2      13.24       6452.190332
# 3      11.20      10884.464286
# 4      28.26       3659.129512
# ..       ...               ...
# 79     13.92      13594.468391
# 80     11.62      15372.547332
# 81     28.30      11953.745583
# 82     28.34      11992.872265
# 83     28.39       7572.455090
#
# [84 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

for iod in IODepth:
#     print(iod)
    blocking=df[(df["isPolling"]==0)&(df["iodepth"]==iod)]
    blocking=blocking.sort_values(by="ActualIOPS")

    polling=df[(df["isPolling"]==1)&(df["iodepth"]==iod)]
    polling=polling.sort_values(by="ActualIOPS")
    
    ax = polling.plot.line(x="ActualIOPS",y="P99_lat",label="polling-P99_clat")
    blocking.plot.line(x="ActualIOPS",y="P99_lat",ax=ax, label="blocking-P99_clat")
    ax.set_title(label="IODepth=%d, P99_clat" % (iod))
    
    ax.set_xlim([0,400000])
    ax.set_ylim([10000, 50000])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
for iod in IODepth:
#     print(iod)
    blocking=df[(df["isPolling"]==0)&(df["iodepth"]==iod)]
    blocking=blocking.sort_values(by="ActualIOPS")

    polling=df[(df["isPolling"]==1)&(df["iodepth"]==iod)]
    polling=polling.sort_values(by="ActualIOPS")

    
    ax1 = polling.plot.line(x="ActualIOPS",y="CPU_util",label="polling-iops_per_cpuutil")
    blocking.plot.line(x="ActualIOPS",y="CPU_util",ax=ax1, label="blocking-iops_per_cpuutil")
    ax1.set_title(label="IODepth=%d, CPU-utilization" % (iod))
    ax1.set_xlim([0,400000])
    ax1.set_ylim([0,30])

#     ax2 = polling.plot.line(x="ActualIOPS",y="iops_per_cpuutil",label="polling-iops_per_cpuutil")
#     blocking.plot.line(x="ActualIOPS",y="iops_per_cpuutil",ax=ax2, label="blocking-iops_per_cpuutil")
#     ax2.set_title(label="IODepth=%d, iops_per_cpuutil" % (iod))
#     ax2.set_xlim([0,400000])
#     ax2.set_ylim([0, 20000])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# /home/taoluo/.conda/envs/fio/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
for iod in IODepth:
#     print(iod)
    blocking=df[(df["isPolling"]==0)&(df["iodepth"]==iod)]
    blocking=blocking.sort_values(by="ActualIOPS")

    polling=df[(df["isPolling"]==1)&(df["iodepth"]==iod)]
    polling=polling.sort_values(by="ActualIOPS")

    
#     ax1 = polling.plot.line(x="ActualIOPS",y="CPU_util",label="polling-iops_per_cpuutil")
#     blocking.plot.line(x="ActualIOPS",y="CPU_util",ax=ax1, label="blocking-iops_per_cpuutil")
#     ax1.set_title(label="IODepth=%d, CPU-utilization" % (iod))
#     ax1.set_xlim([0,400000])
#     ax1.set_ylim([0,30])

    ax2 = polling.plot.line(x="ActualIOPS",y="iops_per_cpuutil",label="polling-iops_per_cpuutil")
    blocking.plot.line(x="ActualIOPS",y="iops_per_cpuutil",ax=ax2, label="blocking-iops_per_cpuutil")
    ax2.set_title(label="IODepth=%d, iops_per_cpuutil" % (iod))
    ax2.set_xlim([0,400000])
    ax2.set_ylim([0, 20000])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
